# %% [markdown]
# Universidade Federal de Alagoas
#
# Instituto de Computação
#
#
# Disciplina: Sistemas Distribuídos
#
# Semestre letivo: 2018.2
#
# Professor: André Lage Freitas
#
#
# # Trabalho Prático AB2
#
# **Importante**. Leia atentamente as especificações pois só serão aceitos trabalhos que as obedecerem.
#
#
# ## Parte 1: Implementação de um monitor de carga da trabalho descentralizado
#
# **Implementar uma versão modificada do detector de falha não confiável** (_unreliable failure detector_) descrito na Seção _15.1.1 Failure assumptions and failure detectors_ do livro a seguir:
#
# Coulouris, Dollimore, Kindberg and Blair, _Distributed Systems: Concepts and Design_. Addison-Wesley, 2012.
#
# A **modificação** consiste em enviar informações sobre a carga do sistema (_system workload_) em vez de informações sobre falhas que indicariam os processos suspeitos e não-suspeitos. Para isso, em vez de cada processo enviar mensagem do tipo `I'm p and I'm alive`, os processos enviarão a medição interna da sua carga de trabalho.
#
# Para simular a medição da carga de trabalho dos processos, utilize números aleatórios entre `0` e `1` com precisão de uma casa decimal apenas, por exemplo, `0.4`.
#
# Utilize como período de envio das mensagens `2` segundos.
#
# ### Detalhes de implementação
#
# Cada processo do sistema deverá ser implementado como um Julia Worker. O Master será apenas o gestor do experimento, ou seja, será responsável para criar os processos (Julia Workers) e iniciar o sistema. Uma vez iniciado, o sistema deve funcionar por si sem depender do Master; uma vez que o algoritmo é descentralizado.
#
# Para fins de visualização do monitoramento da carga de trabalho, os **Workers devem enviar ao Master** periodicamente (a cada `2` segundos) uma mensagem com o estado dos workers que eles monitoram (incluindo ele mesmo). Essa mensagem deve ser impresso na tela do master da seguinte forma.
#
# ```julia
# [...]
# Workload from Worker 4: [0.4,0.9,0.7]
# Workload from Worker 2: [0.4,0.9,0.7]
# Workload from Worker 3: [0.4,0.9,0.7]
# [...]
# ```
#
# A última linha acima significa que as cargas de trabalho dos Workers monitorados pelo Worker 3 são `0.4,0.9,0.7`, ou seja, os Workers têm as seguintes carga de trabalho:
#
# * Worker 2 = 0.4
# * Worker 3 = 0.9
# * Worker 4 = 0.7
#
# Lembre-se de que, em Julia, o ID do Master é 1 e os Workers têm ID maiores que 1.
#
# ## Parte 2: Implementação de um algoritmo de Eleição
#
# **Implementar o algoritmo de Eleição** baseado em anel (_ring-based election algorithm_) descrito na Seção _15.3 Elections_ do livro a seguir:
#
# Coulouris, Dollimore, Kindberg and Blair, _Distributed Systems: Concepts and Design_. Addison-Wesley, 2012.
#
# Considere as seguintes condições.
#
# 1. Uma eleição nova é disparada **quando a carga de trabalho do líder for maior ou igual a `0.8`** e **o Worker que identificou essa alta carga de trabalho do líder tenha carga de trabalho menor que `0.8`**.
# 1. Em caso de empate, o Worker com ID mais alto ganha a eleição.
# 1. Caso não haja Worker com carga de trabalho menor que `0.8` para liderar, escolhe-se o Worker com menor carga de trabalho.
#
# Quando um líder for eleito, ele deve enviar a a seguinte mensagem ao Master:
#
# ```julia
# [...]
# New leader elected! Worker 2
# [...]
# ```
#
#
# ### Suporte de programação distribuída em Julia
#
# Para utilizar o suporte de programação distribuída em Julia, primeiro devemos carergar a biblioteca `Distributed`:
#
# ```julia
# using Pkg
# Pkg.add("Distributed")
# using Distributed
# ```
#
# A seguir, segue uma lista (não extensiva) de funções que poderão ajudar na programação distribuída para a implementação do trabalho:
#
# ```julia
# addprocs
# remotecall
# @fetchfrom
# @everywhere
# sleep
# @spawn
# ```
#
# Para buscar uma rápida ajuda sobre as funções, utilize `?` na frente da função (ver exemplo abaixo).
#
# ```julia
# ?addprocs
# ```
#
# Utilize o [material do mini-curso do Professor](https://github.com/proflage/2018-julia-hands-on) para estudo e a [documentação oficial da linguagem Julia (1.x)](https://docs.julialang.org/en/v1/) para demais dúvidas.
#
# ## Código-fonte
#
# Documente seu código em comentários no próprio código-fonte.
#
# **Todo o seu código tem que estar colado na próxima célula**, mesmo se ele tenha sido feito em IDEs, células separadas, etc. O Professor testará a apenas o que estiver colado na próxima célula.

# %%
# using Pkg
# Pkg.add("Distributed")
using Distributed

# create workers
rmprocs(workers())
addprocs(3)

# returns a random number between 0 and 1
@everywhere function get_self_workload()
    return round(rand(), digits = 1)
end

@everywhere function set_watched_workload(worker, workload)
    watched_workloads[worker] = workload
end

# sends the worker's workload to every other worker in the group
@everywhere function broadcast_self_workload()
    for p in sorted_group
        if p != myid()
            remotecall(set_watched_workload, p, myid(), watched_workloads[myid()])
        end
    end
end

# get next ring neighbor
@everywhere function get_neighbor()
    my_idx = findfirst(id -> id == myid(), sorted_group)
    next_idx = (my_idx % length(sorted_group)) + 1
    return sorted_group[next_idx]
end

# sets the new leader and transmit an "elected message" to the next neighbor
@everywhere function finish_election(new_leader)
    
    # the message has passed through every one and returned to the leader
    if new_leader == myid() && !participating
        return
    end
    
    global participating = false
    global leader = new_leader
    global current_election_leader = -1
    global current_election_workload = 1
    
    # sends the "elected message" to the next neighbor
    remotecall(finish_election, get_neighbor(), new_leader)
end

# sends an "election message" to the next neighbor
@everywhere function pass_election(new_leader, new_leader_workload)
    
    # message has passed through every neighbor and returned to "me"
    if new_leader == myid()
        remotecall(println, 1, "New leader elected! Worker $new_leader")
        finish_election(new_leader)
        return
    end
    
    # already in an election and the new proposal is not better than the current one
    if participating && (new_leader_workload > current_election_workload || (new_leader_workload == current_election_workload && new_leader <= current_election_leader))
        return
    end
    
    
    my_workload = watched_workloads[myid()]
    # checks if the current worker is better than the current "new leader"
    if my_workload < new_leader_workload || (my_workload == new_leader_workload && myid() > new_leader)
        new_leader = myid()
        new_leader_workload = my_workload
    end
    
    global current_election_leader = new_leader
    global current_election_workload = new_leader_workload
    global participating = true

    # forwards the "election message" to the next neighbor
    remotecall(pass_election, get_neighbor(), new_leader, new_leader_workload)
end

# verifies if an election for a new leader is needed
@everywhere function start_election()
    
    # election already happening
    if participating
        return
    end
    
    # worker detected overload on the leader and can be the new leader
    if watched_workloads[leader] >= 0.8 && watched_workloads[myid()] < 0.8
        global participating = true
        
        # sends an "election message" to be the new leader
        remotecall(pass_election, get_neighbor(), myid(), watched_workloads[myid()])
    end
end

@everywhere function run()
    while true
        watched_workloads[myid()] = get_self_workload()
        broadcast_self_workload()
        sleep(2)
        
        remotecall(println, 1, "Workload from Worker $(myid()): $([watched_workloads[p] for p in sorted_group])")
        start_election()
    end
end

@everywhere function init(group)
    global sorted_group = sort(group)
    global watched_workloads = Dict([p => 0.0 for p in sorted_group])
    
    global participating = false
    global leader = sorted_group[1]
    global current_election_leader = -1
    global current_election_workload = 1
    
    run()
end


# boot the system
@sync for p in workers()
    @spawnat p init(workers())
end
# Out:
# ┌ Warning: rmprocs: process 1 not removed
# └ @ Distributed C:\cygwin\home\Administrator\buildbot\worker\package_win64\build\usr\share\julia\stdlib\v1.1\Distributed\src\cluster.jl:928
# Workload from Worker 4: [0.4, 0.0, 0.4]
# Workload from Worker 2: [0.4, 0.0, 0.4]
# Workload from Worker 3: [0.8, 0.0, 0.5]
# New leader elected! Worker 3
# Workload from Worker 2: [0.8, 0.9, 0.5]
# Workload from Worker 4: [0.7, 0.9, 0.5]
# New leader elected! Worker 4
# Workload from Worker 3: [0.7, 0.9, 0.1]
# Workload from Worker 2: [0.7, 0.4, 0.1]
# Workload from Worker 4: [0.2, 0.4, 0.1]
# Workload from Worker 3: [0.2, 0.4, 0.0]
# Workload from Worker 2: [0.2, 0.9, 0.0]
# Workload from Worker 4: [0.6, 0.9, 0.0]
# Workload from Worker 3: [0.6, 0.9, 0.7]
# Workload from Worker 2: [0.6, 0.4, 0.7]
# Workload from Worker 4: [0.5, 0.4, 0.7]
# Workload from Worker 3: [0.5, 0.4, 0.9]
# New leader elected! Worker 3
# Workload from Worker 2: [0.5, 0.5, 0.9]
# Workload from Worker 4: [0.7, 0.5, 0.9]
# Workload from Worker 3: [0.7, 0.5, 0.3]
# Workload from Worker 2: [0.7, 0.3, 0.3]
# Workload from Worker 4: [0.6, 0.3, 0.3]
# Workload from Worker 3: [0.6, 0.3, 0.6]
# Workload from Worker 2: [0.6, 0.7, 0.6]
# Workload from Worker 4: [0.9, 0.7, 0.6]
# Workload from Worker 3: [0.9, 0.7, 0.3]
# Workload from Worker 2: [0.9, 0.8, 0.3]
# Workload from Worker 4: [0.9, 0.8, 0.3]
# New leader elected! Worker 4
# Workload from Worker 3: [0.9, 0.8, 0.0]
# Workload from Worker 2: [0.9, 1.0, 0.0]
# Workload from Worker 4: [0.9, 1.0, 0.0]
# Workload from Worker 3: [0.9, 1.0, 0.7]
# Workload from Worker 2: [0.9, 0.7, 0.7]
# Workload from Worker 4: [1.0, 0.7, 0.7]
# Workload from Worker 3: [1.0, 0.7, 0.2]
# Workload from Worker 2: [1.0, 0.6, 0.2]
# Workload from Worker 4: [0.8, 0.6, 0.2]
# Workload from Worker 3: [0.8, 0.6, 0.1]
# Workload from Worker 2: [0.8, 0.8, 0.1]
# Workload from Worker 4: [0.5, 0.8, 0.1]
# Workload from Worker 3: [0.5, 0.8, 1.0]
# Workload from Worker 2: [0.5, 0.8, 1.0]
# New leader elected! Worker 2
# Workload from Worker 4: [0.3, 0.8, 1.0]
# Workload from Worker 3: [0.3, 0.8, 0.8]
# Workload from Worker 2: [0.3, 0.5, 0.8]
# Workload from Worker 4: [0.8, 0.5, 0.8]
# Workload from Worker 3: [0.8, 0.5, 0.6]
# New leader elected! Worker 3
# InterruptException:
#
# Stacktrace:
#  [1] try_yieldto(::typeof(Base.ensure_rescheduled), ::Base.RefValue{Task}) at .\event.jl:196
#  [2] wait() at .\event.jl:255
#  [3] wait(::Condition) at .\event.jl:46
#  [4] wait_impl at .\channels.jl:362 [inlined]
#  [5] wait at .\channels.jl:358 [inlined]
#  [6] take_buffered(::Channel{Any}) at .\channels.jl:317
#  [7] take!(::Channel{Any}) at .\channels.jl:315
#  [8] take!(::Distributed.RemoteValue) at C:\cygwin\home\Administrator\buildbot\worker\package_win64\build\usr\share\julia\stdlib\v1.1\Distributed\src\remotecall.jl:576
#  [9] #remotecall_fetch#149(::Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}}, ::Function, ::Function, ::Distributed.Worker, ::Distributed.RRID, ::Vararg{Any,N} where N) at C:\cygwin\home\Administrator\buildbot\worker\package_win64\build\usr\share\julia\stdlib\v1.1\Distributed\src\remotecall.jl:375
#  [10] remotecall_fetch(::Function, ::Distributed.Worker, ::Distributed.RRID, ::Vararg{Any,N} where N) at C:\cygwin\home\Administrator\buildbot\worker\package_win64\build\usr\share\julia\stdlib\v1.1\Distributed\src\remotecall.jl:371
#  [11] #remotecall_fetch#152(::Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}}, ::Function, ::Function, ::Int64, ::Distributed.RRID, ::Vararg{Any,N} where N) at C:\cygwin\home\Administrator\buildbot\worker\package_win64\build\usr\share\julia\stdlib\v1.1\Distributed\src\remotecall.jl:406
#  [12] call_on_owner at C:\cygwin\home\Administrator\buildbot\worker\package_win64\build\usr\share\julia\stdlib\v1.1\Distributed\src\remotecall.jl:406 [inlined]
#  [13] wait(::Future) at C:\cygwin\home\Administrator\buildbot\worker\package_win64\build\usr\share\julia\stdlib\v1.1\Distributed\src\remotecall.jl:500
#  [14] sync_end(::Array{Any,1}) at .\task.jl:213
#  [15] top-level scope at task.jl:245
#  [16] top-level scope at In[1]:122
# Workload from Worker 2: [0.8, 0.3, 0.6]
# Workload from Worker 4: [0.1, 0.3, 0.6]
# Workload from Worker 3: [0.1, 0.3, 0.8]
# Workload from Worker 2: [0.1, 0.9, 0.8]
# New leader elected! Worker 2
# Workload from Worker 4: [0.2, 0.9, 0.8]
# Workload from Worker 3: [0.2, 0.9, 0.2]
# Workload from Worker 2: [0.2, 0.5, 0.2]
# Workload from Worker 4: [0.4, 0.5, 0.2]
# Workload from Worker 3: [0.4, 0.5, 0.9]
# Workload from Worker 2: [0.4, 0.4, 0.9]
# Workload from Worker 4: [0.3, 0.4, 0.9]
# Workload from Worker 3: [0.3, 0.4, 0.7]
# Workload from Worker 2: [0.3, 0.9, 0.7]
# Workload from Worker 4: [0.1, 0.9, 0.7]
# Workload from Worker 3: [0.1, 0.9, 0.1]
# Workload from Worker 2: [0.1, 0.2, 0.1]
# Workload from Worker 4: [1.0, 0.2, 0.1]
# New leader elected! Worker 4
# Workload from Worker 3: [1.0, 0.2, 0.9]
# New leader elected! Worker 3
# Workload from Worker 2: [1.0, 0.8, 0.9]
# Workload from Worker 4: [0.6, 0.8, 0.9]
# Workload from Worker 3: [0.6, 0.8, 0.5]
# Workload from Worker 2: [0.6, 0.5, 0.5]
# Workload from Worker 4: [0.6, 0.5, 0.5]
# Workload from Worker 3: [0.6, 0.5, 0.6]
# Workload from Worker 2: [0.6, 0.1, 0.6]
# Workload from Worker 4: [1.0, 0.1, 0.6]
# Workload from Worker 3: [1.0, 0.1, 0.6]
# Workload from Worker 2: [1.0, 0.6, 0.6]
# Workload from Worker 4: [0.8, 0.6, 0.6]
# Workload from Worker 3: [0.8, 0.6, 0.1]
# Workload from Worker 2: [0.8, 0.7, 0.1]
# Workload from Worker 4: [0.4, 0.7, 0.1]
# Workload from Worker 3: [0.4, 0.7, 0.4]
# Workload from Worker 2: [0.4, 0.9, 0.4]
# Workload from Worker 4: [0.1, 0.9, 0.4]
# New leader elected! Worker 2
# Workload from Worker 3: [0.1, 0.9, 0.6]
# Workload from Worker 2: [0.1, 0.4, 0.6]
# Workload from Worker 4: [0.8, 0.4, 0.6]
# New leader elected! Worker 4
# Workload from Worker 3: [0.8, 0.4, 0.1]
# Workload from Worker 2: [0.8, 0.4, 0.1]
# Workload from Worker 4: [0.1, 0.4, 0.1]
# Workload from Worker 3: [0.1, 0.4, 0.5]
# Workload from Worker 2: [0.1, 0.9, 0.5]
# Workload from Worker 4: [0.2, 0.9, 0.5]
# Workload from Worker 3: [0.2, 0.9, 0.9]
# Workload from Worker 2: [0.2, 0.3, 0.9]
# New leader elected! Worker 2
# Workload from Worker 4: [0.7, 0.3, 0.9]
# Workload from Worker 3: [0.7, 0.3, 0.5]
# Workload from Worker 2: [0.7, 0.6, 0.5]
# Workload from Worker 4: [0.9, 0.6, 0.5]
# New leader elected! Worker 4
# Workload from Worker 3: [0.9, 0.6, 0.2]
# Workload from Worker 2: [0.9, 0.5, 0.2]
# Workload from Worker 4: [0.4, 0.5, 0.2]
# Workload from Worker 3: [0.4, 0.5, 0.1]
# Workload from Worker 2: [0.4, 0.9, 0.1]
# Workload from Worker 4: [0.2, 0.9, 0.1]
# Workload from Worker 3: [0.2, 0.9, 0.1]
# Workload from Worker 2: [0.2, 0.5, 0.1]
# Workload from Worker 4: [0.6, 0.5, 0.1]
# Workload from Worker 3: [0.6, 0.5, 0.0]
# Workload from Worker 2: [0.6, 0.7, 0.0]
# Workload from Worker 4: [0.7, 0.7, 0.0]
# Workload from Worker 3: [0.7, 0.7, 0.0]
# Workload from Worker 2: [0.7, 0.9, 0.0]
# Workload from Worker 4: [0.4, 0.9, 0.0]
# Workload from Worker 3: [0.4, 0.9, 0.8]
# Workload from Worker 2: [0.4, 0.2, 0.8]
# New leader elected! Worker 2
# Workload from Worker 4: [0.1, 0.2, 0.8]
# Workload from Worker 3: [0.1, 0.2, 0.4]
# Workload from Worker 2: [0.1, 0.4, 0.4]
# Workload from Worker 4: [0.6, 0.4, 0.4]
# Workload from Worker 3: [0.6, 0.4, 1.0]
# Workload from Worker 2: [0.6, 0.8, 1.0]
# Workload from Worker 4: [0.7, 0.8, 1.0]
# Workload from Worker 3: [0.7, 0.8, 0.9]
# Workload from Worker 2: [0.7, 0.2, 0.9]
# Workload from Worker 4: [1.0, 0.2, 0.9]
# Workload from Worker 3: [1.0, 0.2, 0.7]
# New leader elected! Worker 3
# Workload from Worker 2: [1.0, 0.4, 0.7]
# Workload from Worker 4: [0.1, 0.4, 0.7]
# Workload from Worker 3: [0.1, 0.4, 0.2]
# Workload from Worker 2: [0.1, 0.3, 0.2]
# Workload from Worker 4: [0.8, 0.3, 0.2]
# Workload from Worker 3: [0.8, 0.3, 0.6]
# Workload from Worker 2: [0.8, 0.2, 0.6]
# Workload from Worker 4: [0.5, 0.2, 0.6]
# Workload from Worker 3: [0.5, 0.2, 0.5]
# Workload from Worker 2: [0.5, 0.1, 0.5]
# Workload from Worker 4: [0.1, 0.1, 0.5]
# Workload from Worker 3: [0.1, 0.1, 0.7]
# Workload from Worker 2: [0.1, 0.1, 0.7]
# Workload from Worker 4: [0.1, 0.1, 0.7]
# Workload from Worker 3: [0.1, 0.1, 0.7]
# Workload from Worker 2: [0.1, 0.4, 0.7]
# Workload from Worker 4: [0.7, 0.4, 0.7]
# Workload from Worker 3: [0.7, 0.4, 1.0]
# Workload from Worker 2: [0.7, 0.8, 1.0]
# New leader elected! Worker 2
# Workload from Worker 4: [0.8, 0.8, 1.0]
# Workload from Worker 3: [0.8, 0.8, 0.3]
# Workload from Worker 2: [0.8, 0.7, 0.3]
# Workload from Worker 4: [0.6, 0.7, 0.3]
# Workload from Worker 3: [0.6, 0.7, 0.5]
# Workload from Worker 2: [0.6, 0.3, 0.5]
# Workload from Worker 4: [0.8, 0.3, 0.5]
# New leader elected! Worker 4
# Workload from Worker 3: [0.8, 0.3, 0.3]
# Workload from Worker 2: [0.8, 0.2, 0.3]
# Workload from Worker 4: [0.2, 0.2, 0.3]
# Workload from Worker 3: [0.2, 0.2, 0.0]
# Workload from Worker 2: [0.2, 0.7, 0.0]
# Workload from Worker 4: [0.3, 0.7, 0.0]
# Workload from Worker 3: [0.3, 0.7, 0.3]
# Workload from Worker 2: [0.3, 0.8, 0.3]
# Workload from Worker 4: [0.0, 0.8, 0.3]
# Workload from Worker 3: [0.0, 0.8, 0.6]
# Workload from Worker 2: [0.0, 0.9, 0.6]
# Workload from Worker 4: [0.3, 0.9, 0.6]
# Workload from Worker 3: [0.3, 0.9, 0.4]
# Workload from Worker 2: [0.3, 0.2, 0.4]
# Workload from Worker 4: [0.3, 0.2, 0.4]
# Workload from Worker 3: [0.3, 0.2, 0.5]
# Workload from Worker 2: [0.3, 0.4, 0.5]
# Workload from Worker 4: [0.2, 0.4, 0.5]
# Workload from Worker 3: [0.2, 0.4, 0.9]
# New leader elected! Worker 2
# Workload from Worker 2: [0.2, 0.8, 0.9]
# Workload from Worker 4: [0.3, 0.8, 0.9]
# Workload from Worker 3: [0.3, 0.8, 0.1]
# Workload from Worker 2: [0.3, 0.2, 0.1]
# Workload from Worker 4: [0.4, 0.2, 0.1]
# Workload from Worker 3: [0.4, 0.2, 0.7]
# Workload from Worker 2: [0.4, 0.1, 0.7]
# Workload from Worker 4: [0.2, 0.1, 0.7]
# Workload from Worker 3: [0.2, 0.1, 0.7]
# Workload from Worker 2: [0.2, 0.9, 0.7]
# Workload from Worker 4: [0.6, 0.9, 0.7]
# Workload from Worker 3: [0.6, 0.9, 0.8]
# Workload from Worker 2: [0.6, 0.3, 0.8]
# Workload from Worker 4: [0.1, 0.3, 0.8]
# Workload from Worker 3: [0.1, 0.3, 0.2]
# Workload from Worker 2: [0.1, 0.3, 0.2]
# Workload from Worker 4: [0.2, 0.3, 0.2]
# Workload from Worker 3: [0.2, 0.3, 0.6]
# Workload from Worker 2: [0.2, 0.3, 0.6]
# Workload from Worker 4: [0.5, 0.3, 0.6]
# Workload from Worker 3: [0.5, 0.3, 0.2]
# Workload from Worker 2: [0.5, 0.3, 0.2]
# Workload from Worker 4: [0.7, 0.3, 0.2]
# Workload from Worker 3: [0.7, 0.3, 0.9]
# Workload from Worker 2: [0.7, 0.3, 0.9]
# Workload from Worker 4: [0.1, 0.3, 0.9]
# Workload from Worker 3: [0.1, 0.3, 0.1]
# Workload from Worker 2: [0.1, 0.5, 0.1]
# Workload from Worker 4: [0.9, 0.5, 0.1]
# New leader elected! Worker 4
# Workload from Worker 3: [0.9, 0.5, 0.2]
# Workload from Worker 2: [0.9, 0.9, 0.2]
# Workload from Worker 4: [0.8, 0.9, 0.2]
# Workload from Worker 3: [0.8, 0.9, 0.4]
# Workload from Worker 2: [0.8, 0.4, 0.4]
# Workload from Worker 4: [0.6, 0.4, 0.4]
# Workload from Worker 3: [0.6, 0.4, 0.2]
# Workload from Worker 2: [0.6, 0.3, 0.2]
# Workload from Worker 4: [0.2, 0.3, 0.2]
# Workload from Worker 3: [0.2, 0.3, 0.2]
# Workload from Worker 2: [0.2, 0.1, 0.2]
# Workload from Worker 4: [0.4, 0.1, 0.2]
# Workload from Worker 3: [0.4, 0.1, 0.4]
# Workload from Worker 2: [0.4, 0.8, 0.4]
# Workload from Worker 4: [0.7, 0.8, 0.4]
# Workload from Worker 3: [0.7, 0.8, 0.6]
# Workload from Worker 2: [0.7, 0.7, 0.6]
# Workload from Worker 4: [0.9, 0.7, 0.6]
# Workload from Worker 3: [0.9, 0.7, 0.4]
# Workload from Worker 2: [0.9, 0.9, 0.4]
# Workload from Worker 4: [0.4, 0.9, 0.4]
# Workload from Worker 3: [0.4, 0.9, 0.8]
# Workload from Worker 2: [0.4, 0.8, 0.8]
# New leader elected! Worker 2
# Workload from Worker 4: [0.9, 0.8, 0.8]
# Workload from Worker 3: [0.9, 0.8, 0.8]
# Workload from Worker 2: [0.9, 0.3, 0.8]
# Workload from Worker 4: [0.9, 0.3, 0.8]
# Workload from Worker 3: [0.9, 0.3, 0.6]
# New leader elected! Worker 3
# Workload from Worker 2: [0.9, 0.7, 0.6]
# Workload from Worker 4: [0.5, 0.7, 0.6]
# Workload from Worker 3: [0.5, 0.7, 0.6]
# Workload from Worker 2: [0.5, 0.7, 0.6]
# Workload from Worker 4: [0.4, 0.7, 0.6]
# Workload from Worker 3: [0.4, 0.7, 0.6]
# Workload from Worker 2: [0.4, 0.9, 0.6]
# New leader elected! Worker 2
# Workload from Worker 4: [0.5, 0.9, 0.6]
# Workload from Worker 3: [0.5, 0.9, 0.0]
# Workload from Worker 2: [0.5, 0.2, 0.0]
# Workload from Worker 4: [0.3, 0.2, 0.0]
# Workload from Worker 3: [0.3, 0.2, 0.7]
# Workload from Worker 2: [0.3, 0.5, 0.7]
# Workload from Worker 4: [0.1, 0.5, 0.7]
# Workload from Worker 3: [0.1, 0.5, 0.5]
# Workload from Worker 2: [0.1, 0.2, 0.5]
# Workload from Worker 4: [0.5, 0.2, 0.5]
# Workload from Worker 3: [0.5, 0.2, 0.6]
# Workload from Worker 2: [0.5, 0.6, 0.6]
# Workload from Worker 4: [1.0, 0.6, 0.6]
# New leader elected! Worker 4
# Workload from Worker 3: [1.0, 0.6, 0.5]
# Workload from Worker 2: [1.0, 0.5, 0.5]
# Workload from Worker 4: [0.4, 0.5, 0.5]
# Workload from Worker 3: [0.4, 0.5, 0.5]
# Workload from Worker 2: [0.4, 0.8, 0.5]
# Workload from Worker 4: [0.2, 0.8, 0.5]
# Workload from Worker 3: [0.2, 0.8, 0.6]
# Workload from Worker 2: [0.2, 0.1, 0.6]
# Workload from Worker 4: [0.7, 0.1, 0.6]
# Workload from Worker 3: [0.7, 0.1, 0.1]
# Workload from Worker 2: [0.7, 0.5, 0.1]
# Workload from Worker 4: [0.7, 0.5, 0.1]
# Workload from Worker 3: [0.7, 0.5, 0.8]
# New leader elected! Worker 3
# Workload from Worker 2: [0.7, 0.2, 0.8]
# Workload from Worker 4: [0.7, 0.2, 0.8]
# Workload from Worker 3: [0.7, 0.2, 0.6]
# Workload from Worker 2: [0.7, 0.1, 0.6]
# Workload from Worker 4: [0.6, 0.1, 0.6]
# Workload from Worker 3: [0.6, 0.1, 0.5]
# Workload from Worker 2: [0.6, 0.8, 0.5]
# New leader elected! Worker 4
# Workload from Worker 4: [0.5, 0.8, 0.5]
# Workload from Worker 3: [0.5, 0.8, 0.1]
# Workload from Worker 2: [0.5, 0.2, 0.1]
# Workload from Worker 4: [0.5, 0.2, 0.1]
# Workload from Worker 3: [0.5, 0.2, 0.3]
# Workload from Worker 2: [0.5, 1.0, 0.3]
# Workload from Worker 4: [0.8, 1.0, 0.3]
# Workload from Worker 3: [0.8, 1.0, 0.4]
# Workload from Worker 2: [0.8, 0.4, 0.4]
# Workload from Worker 4: [0.1, 0.4, 0.4]
# Workload from Worker 3: [0.1, 0.4, 0.5]
# Workload from Worker 2: [0.1, 0.5, 0.5]
# Workload from Worker 4: [0.3, 0.5, 0.5]
# Workload from Worker 3: [0.3, 0.5, 0.3]
# Workload from Worker 2: [0.3, 0.8, 0.3]
# Workload from Worker 4: [0.2, 0.8, 0.3]
# Workload from Worker 3: [0.2, 0.8, 0.8]
# Workload from Worker 2: [0.2, 0.3, 0.8]
# New leader elected! Worker 2
# Workload from Worker 4: [1.0, 0.3, 0.8]
# Workload from Worker 3: [1.0, 0.3, 0.8]
# New leader elected! Worker 3
# Workload from Worker 2: [1.0, 0.9, 0.8]
# Workload from Worker 4: [0.9, 0.9, 0.8]
# Workload from Worker 3: [0.9, 0.9, 0.1]
# Workload from Worker 2: [0.9, 0.3, 0.1]
# Workload from Worker 4: [0.7, 0.3, 0.1]
# Workload from Worker 3: [0.7, 0.3, 1.0]
# Workload from Worker 2: [0.7, 0.9, 1.0]
# New leader elected! Worker 2
# Workload from Worker 4: [0.2, 0.9, 1.0]
# Workload from Worker 3: [0.2, 0.9, 0.7]
# Workload from Worker 2: [0.2, 0.6, 0.7]
# Workload from Worker 4: [1.0, 0.6, 0.7]
# New leader elected! Worker 3
# Workload from Worker 3: [1.0, 0.6, 1.0]
# Workload from Worker 2: [1.0, 0.3, 1.0]
# Workload from Worker 4: [1.0, 0.3, 1.0]
# Workload from Worker 3: [1.0, 0.3, 0.4]
# Workload from Worker 2: [1.0, 0.6, 0.4]
# Workload from Worker 4: [0.8, 0.6, 0.4]
# Workload from Worker 3: [0.8, 0.6, 0.7]
# Workload from Worker 2: [0.8, 0.9, 0.7]
# Workload from Worker 4: [0.2, 0.9, 0.7]
# New leader elected! Worker 2
# Workload from Worker 3: [0.2, 0.9, 0.5]
# Workload from Worker 2: [0.2, 0.2, 0.5]
# Workload from Worker 4: [0.1, 0.2, 0.5]
# Workload from Worker 3: [0.1, 0.2, 0.5]
# Workload from Worker 2: [0.1, 0.3, 0.5]
# Workload from Worker 4: [0.8, 0.3, 0.5]
# New leader elected! Worker 3
# Workload from Worker 3: [0.8, 0.3, 0.5]
# Workload from Worker 2: [0.8, 0.5, 0.5]
# Workload from Worker 4: [0.1, 0.5, 0.5]
# Workload from Worker 3: [0.1, 0.5, 0.9]
# Workload from Worker 2: [0.1, 0.5, 0.9]
# Workload from Worker 4: [0.9, 0.5, 0.9]
# Workload from Worker 3: [0.9, 0.5, 0.7]
# Workload from Worker 2: [0.9, 0.3, 0.7]
# Workload from Worker 4: [0.4, 0.3, 0.7]
# Workload from Worker 3: [0.4, 0.3, 0.6]
# Workload from Worker 2: [0.4, 0.1, 0.6]
# Workload from Worker 4: [0.6, 0.1, 0.6]
# Workload from Worker 3: [0.6, 0.1, 0.1]
# Workload from Worker 2: [0.6, 0.4, 0.1]
# Workload from Worker 4: [0.3, 0.4, 0.1]
# Workload from Worker 3: [0.3, 0.4, 0.0]
# Workload from Worker 2: [0.3, 0.1, 0.0]
# Workload from Worker 4: [0.3, 0.1, 0.0]
# Workload from Worker 3: [0.3, 0.1, 0.8]
# Workload from Worker 2: [0.3, 0.3, 0.8]
# Workload from Worker 4: [0.8, 0.3, 0.8]
# Workload from Worker 3: [0.8, 0.3, 0.7]
# Workload from Worker 2: [0.8, 0.2, 0.7]
# Workload from Worker 4: [0.6, 0.2, 0.7]
# Workload from Worker 3: [0.6, 0.2, 0.5]
# Workload from Worker 2: [0.6, 0.7, 0.5]
# Workload from Worker 4: [0.8, 0.7, 0.5]
# Workload from Worker 3: [0.8, 0.7, 0.5]
# Workload from Worker 2: [0.8, 0.5, 0.5]
# Workload from Worker 4: [0.0, 0.5, 0.5]
# Workload from Worker 3: [0.0, 0.5, 0.9]
# Workload from Worker 2: [0.0, 0.5, 0.9]
# Workload from Worker 4: [0.3, 0.5, 0.9]
# Workload from Worker 3: [0.3, 0.5, 0.4]
# Workload from Worker 2: [0.3, 0.3, 0.4]
# Workload from Worker 4: [1.0, 0.3, 0.4]
# Workload from Worker 3: [1.0, 0.3, 0.5]
# Workload from Worker 2: [1.0, 0.5, 0.5]
# Workload from Worker 4: [0.3, 0.5, 0.5]
# Workload from Worker 3: [0.3, 0.5, 0.3]
# Workload from Worker 2: [0.3, 0.7, 0.3]
# Workload from Worker 4: [0.5, 0.7, 0.3]
# Workload from Worker 3: [0.5, 0.7, 0.3]
# Workload from Worker 2: [0.5, 0.4, 0.3]
# Workload from Worker 4: [0.1, 0.4, 0.3]
# Workload from Worker 3: [0.1, 0.4, 0.1]
# Workload from Worker 2: [0.1, 0.7, 0.1]
# Workload from Worker 4: [0.4, 0.7, 0.1]
# Workload from Worker 3: [0.4, 0.7, 1.0]
# Workload from Worker 2: [0.4, 0.2, 1.0]
# Workload from Worker 4: [0.8, 0.2, 1.0]
# Workload from Worker 3: [0.8, 0.2, 0.9]
# Workload from Worker 2: [0.8, 0.5, 0.9]
# Workload from Worker 4: [0.3, 0.5, 0.9]
# Workload from Worker 3: [0.3, 0.5, 0.1]
# Workload from Worker 2: [0.3, 0.4, 0.1]
# Workload from Worker 4: [0.7, 0.4, 0.1]
# Workload from Worker 3: [0.7, 0.4, 0.8]
# Workload from Worker 2: [0.7, 0.2, 0.8]
# Workload from Worker 4: [0.9, 0.2, 0.8]
# Workload from Worker 3: [0.9, 0.2, 0.8]
# Workload from Worker 2: [0.9, 0.2, 0.8]
# Workload from Worker 4: [0.9, 0.2, 0.8]
# Workload from Worker 3: [0.9, 0.2, 0.8]
# Workload from Worker 2: [0.9, 0.7, 0.8]
# Workload from Worker 4: [0.7, 0.7, 0.8]
# Workload from Worker 3: [0.7, 0.7, 0.1]
# Workload from Worker 2: [0.7, 0.6, 0.1]
# Workload from Worker 4: [0.9, 0.6, 0.1]
# Workload from Worker 3: [0.9, 0.6, 0.2]
# Workload from Worker 2: [0.9, 0.6, 0.2]
# Workload from Worker 4: [0.7, 0.6, 0.2]
# Workload from Worker 3: [0.7, 0.6, 0.5]
# Workload from Worker 2: [0.7, 0.1, 0.5]
# Workload from Worker 4: [0.6, 0.1, 0.5]
# Workload from Worker 3: [0.6, 0.1, 0.7]
# Workload from Worker 2: [0.6, 0.5, 0.7]
# Workload from Worker 4: [1.0, 0.5, 0.7]
# Workload from Worker 3: [1.0, 0.5, 0.7]
# Workload from Worker 2: [1.0, 0.0, 0.7]
# Workload from Worker 4: [0.1, 0.0, 0.7]
# Workload from Worker 3: [0.1, 0.0, 0.3]
# Workload from Worker 2: [0.1, 0.9, 0.3]
# New leader elected! Worker 2
# Workload from Worker 4: [0.4, 0.9, 0.3]
# Workload from Worker 3: [0.4, 0.9, 0.9]
# Workload from Worker 2: [0.4, 0.9, 0.9]
# Workload from Worker 4: [0.7, 0.9, 0.9]
# Workload from Worker 3: [0.7, 0.9, 0.3]
# Workload from Worker 2: [0.7, 0.3, 0.3]
# Workload from Worker 4: [0.6, 0.3, 0.3]
# Workload from Worker 3: [0.6, 0.3, 1.0]
# Workload from Worker 2: [0.6, 0.7, 1.0]
# Workload from Worker 4: [0.0, 0.7, 1.0]
# Workload from Worker 3: [0.0, 0.7, 0.6]
# Workload from Worker 2: [0.0, 0.1, 0.6]
# Workload from Worker 4: [0.0, 0.1, 0.6]
# Workload from Worker 3: [0.0, 0.1, 0.6]
# Workload from Worker 2: [0.0, 0.7, 0.6]
# Workload from Worker 4: [0.5, 0.7, 0.6]
# Workload from Worker 3: [0.5, 0.7, 0.9]
# Workload from Worker 2: [0.5, 0.3, 0.9]
# Workload from Worker 4: [0.2, 0.3, 0.9]
# Workload from Worker 3: [0.2, 0.3, 0.7]
# Workload from Worker 2: [0.2, 0.7, 0.7]
# Workload from Worker 4: [0.5, 0.7, 0.7]
# Workload from Worker 3: [0.5, 0.7, 0.1]
# Workload from Worker 2: [0.5, 1.0, 0.1]
# Workload from Worker 4: [0.2, 1.0, 0.1]
# Workload from Worker 3: [0.2, 1.0, 0.9]
# Workload from Worker 2: [0.2, 0.8, 0.9]
# Workload from Worker 4: [0.0, 0.8, 0.9]
# Workload from Worker 3: [0.0, 0.8, 0.4]
# Workload from Worker 2: [0.0, 0.4, 0.4]
# Workload from Worker 4: [0.2, 0.4, 0.4]
# Workload from Worker 3: [0.2, 0.4, 0.5]
# Workload from Worker 2: [0.2, 0.3, 0.5]
# Workload from Worker 4: [0.8, 0.3, 0.5]
# New leader elected! Worker 3
# Workload from Worker 3: [0.8, 0.3, 0.5]
# Workload from Worker 2: [0.8, 1.0, 0.5]
# Workload from Worker 4: [0.9, 1.0, 0.5]
# New leader elected! Worker 4
# Workload from Worker 3: [0.9, 1.0, 0.7]
# Workload from Worker 2: [0.9, 0.6, 0.7]
# Workload from Worker 4: [0.7, 0.6, 0.7]
# Workload from Worker 3: [0.7, 0.6, 0.1]
# Workload from Worker 2: [0.7, 0.0, 0.1]
# Workload from Worker 4: [0.6, 0.0, 0.1]
# Workload from Worker 3: [0.6, 0.0, 0.2]
# Workload from Worker 2: [0.6, 0.1, 0.2]
# Workload from Worker 4: [1.0, 0.1, 0.2]
# Workload from Worker 3: [1.0, 0.1, 0.5]
# Workload from Worker 2: [1.0, 0.2, 0.5]
# Workload from Worker 4: [0.8, 0.2, 0.5]
# Workload from Worker 3: [0.8, 0.2, 0.3]
# Workload from Worker 2: [0.8, 0.5, 0.3]
# Workload from Worker 4: [0.3, 0.5, 0.3]
# Workload from Worker 3: [0.3, 0.5, 0.8]
# New leader elected! Worker 2
# Workload from Worker 2: [0.3, 0.7, 0.8]
# Workload from Worker 4: [0.7, 0.7, 0.8]
# Workload from Worker 3: [0.7, 0.7, 0.9]
# Workload from Worker 2: [0.7, 0.5, 0.9]
# Workload from Worker 4: [0.3, 0.5, 0.9]
# Workload from Worker 3: [0.3, 0.5, 0.6]
# Workload from Worker 2: [0.3, 0.4, 0.6]
# Workload from Worker 4: [0.0, 0.4, 0.6]
# Workload from Worker 3: [0.0, 0.4, 0.3]
# Workload from Worker 2: [0.0, 1.0, 0.3]
# Workload from Worker 4: [0.4, 1.0, 0.3]
# Workload from Worker 3: [0.4, 1.0, 0.2]
# Workload from Worker 2: [0.4, 0.1, 0.2]
# Workload from Worker 4: [0.0, 0.1, 0.2]
# Workload from Worker 3: [0.0, 0.1, 0.2]
# Workload from Worker 2: [0.0, 0.2, 0.2]
# Workload from Worker 4: [0.4, 0.2, 0.2]
# Workload from Worker 3: [0.4, 0.2, 0.5]
# Workload from Worker 2: [0.4, 0.6, 0.5]
# Workload from Worker 4: [0.4, 0.6, 0.5]
# Workload from Worker 3: [0.4, 0.6, 0.3]
# Workload from Worker 2: [0.4, 0.3, 0.3]
# Workload from Worker 4: [0.5, 0.3, 0.3]
# Workload from Worker 3: [0.5, 0.3, 0.9]
# Workload from Worker 2: [0.5, 0.5, 0.9]
# Workload from Worker 4: [0.7, 0.5, 0.9]
# Workload from Worker 3: [0.7, 0.5, 0.8]
# Workload from Worker 2: [0.7, 0.5, 0.8]
# Workload from Worker 4: [0.9, 0.5, 0.8]
# Workload from Worker 3: [0.9, 0.5, 0.8]
# New leader elected! Worker 3
# Workload from Worker 2: [0.9, 0.3, 0.8]
# Workload from Worker 4: [0.6, 0.3, 0.8]
# Workload from Worker 3: [0.6, 0.3, 0.9]
# Workload from Worker 2: [0.6, 0.3, 0.9]
# Workload from Worker 4: [0.7, 0.3, 0.9]
# Workload from Worker 3: [0.7, 0.3, 0.7]
# Workload from Worker 2: [0.7, 0.1, 0.7]
# Workload from Worker 4: [0.5, 0.1, 0.7]
# Workload from Worker 3: [0.5, 0.1, 0.7]
# Workload from Worker 2: [0.5, 1.0, 0.7]
# New leader elected! Worker 2
# Workload from Worker 4: [0.8, 1.0, 0.7]
# New leader elected! Worker 4
# Workload from Worker 3: [0.8, 1.0, 0.6]
# Workload from Worker 2: [0.8, 0.6, 0.6]
# Workload from Worker 4: [0.3, 0.6, 0.6]
# Workload from Worker 3: [0.3, 0.6, 0.8]
# New leader elected! Worker 2
# Workload from Worker 2: [0.3, 0.9, 0.8]
# Workload from Worker 4: [0.1, 0.9, 0.8]
# Workload from Worker 3: [0.1, 0.9, 0.4]
# Workload from Worker 2: [0.1, 0.2, 0.4]
# Workload from Worker 4: [0.2, 0.2, 0.4]
# Workload from Worker 3: [0.2, 0.2, 0.3]
# Workload from Worker 2: [0.2, 0.9, 0.3]
# Workload from Worker 4: [0.8, 0.9, 0.3]
# New leader elected! Worker 4
# Workload from Worker 3: [0.8, 0.9, 0.4]
# Workload from Worker 2: [0.8, 0.1, 0.4]
# Workload from Worker 4: [0.7, 0.1, 0.4]
# Workload from Worker 3: [0.7, 0.1, 0.8]
# New leader elected! Worker 3
# Workload from Worker 2: [0.7, 0.4, 0.8]
# Workload from Worker 4: [0.4, 0.4, 0.8]
# Workload from Worker 3: [0.4, 0.4, 0.2]
# Workload from Worker 2: [0.4, 0.5, 0.2]
# Workload from Worker 4: [0.4, 0.5, 0.2]
# Workload from Worker 3: [0.4, 0.5, 0.5]
# Workload from Worker 2: [0.4, 0.6, 0.5]
# Workload from Worker 4: [0.5, 0.6, 0.5]
# Workload from Worker 3: [0.5, 0.6, 0.3]
# Workload from Worker 2: [0.5, 0.3, 0.3]
# Workload from Worker 4: [0.2, 0.3, 0.3]
# Workload from Worker 3: [0.2, 0.3, 0.5]
# Workload from Worker 2: [0.2, 0.0, 0.5]
# Workload from Worker 4: [0.0, 0.0, 0.5]
# Workload from Worker 3: [0.0, 0.0, 0.9]
# Workload from Worker 2: [0.0, 0.5, 0.9]
# Workload from Worker 4: [0.0, 0.5, 0.9]
# Workload from Worker 3: [0.0, 0.5, 0.3]
# Workload from Worker 2: [0.0, 0.1, 0.3]
# Workload from Worker 4: [0.1, 0.1, 0.3]
# Workload from Worker 3: [0.1, 0.1, 0.8]
# Workload from Worker 2: [0.1, 1.0, 0.8]
# New leader elected! Worker 2
# Workload from Worker 4: [0.5, 1.0, 0.8]
# Workload from Worker 3: [0.5, 1.0, 0.5]
# Workload from Worker 2: [0.5, 0.3, 0.5]
# Workload from Worker 4: [0.0, 0.3, 0.5]
# Workload from Worker 3: [0.0, 0.3, 0.4]
# Workload from Worker 2: [0.0, 0.8, 0.4]
# Workload from Worker 4: [0.5, 0.8, 0.4]
# Workload from Worker 3: [0.5, 0.8, 0.1]
# Workload from Worker 2: [0.5, 0.1, 0.1]
# Workload from Worker 4: [0.3, 0.1, 0.1]
# Workload from Worker 3: [0.3, 0.1, 0.2]
# Workload from Worker 2: [0.3, 0.5, 0.2]
# Workload from Worker 4: [0.3, 0.5, 0.2]
# Workload from Worker 3: [0.3, 0.5, 0.0]
# Workload from Worker 2: [0.3, 0.1, 0.0]
# Workload from Worker 4: [0.1, 0.1, 0.0]
# Workload from Worker 3: [0.1, 0.1, 0.1]
# Workload from Worker 2: [0.1, 0.4, 0.1]
# Workload from Worker 4: [0.5, 0.4, 0.1]
# Workload from Worker 3: [0.5, 0.4, 0.9]
# Workload from Worker 2: [0.5, 0.8, 0.9]
# Workload from Worker 4: [0.0, 0.8, 0.9]
# Workload from Worker 3: [0.0, 0.8, 0.7]
# Workload from Worker 2: [0.0, 0.9, 0.7]
# Workload from Worker 4: [0.6, 0.9, 0.7]
# Workload from Worker 3: [0.6, 0.9, 0.2]
# Workload from Worker 2: [0.6, 0.4, 0.2]
# Workload from Worker 4: [0.3, 0.4, 0.2]
# Workload from Worker 3: [0.3, 0.4, 0.3]
# Workload from Worker 2: [0.3, 0.8, 0.3]
# Workload from Worker 4: [0.9, 0.8, 0.3]
# New leader elected! Worker 4
# Workload from Worker 3: [0.9, 0.8, 0.7]
# Workload from Worker 2: [0.9, 0.4, 0.7]
# Workload from Worker 4: [0.4, 0.4, 0.7]
# Workload from Worker 3: [0.4, 0.4, 0.6]
# Workload from Worker 2: [0.4, 0.5, 0.6]
# Workload from Worker 4: [0.6, 0.5, 0.6]
# Workload from Worker 3: [0.6, 0.5, 0.0]
# Workload from Worker 2: [0.6, 0.9, 0.0]
# Workload from Worker 4: [0.3, 0.9, 0.0]
# Workload from Worker 3: [0.3, 0.9, 0.3]
# Workload from Worker 2: [0.3, 0.4, 0.3]
# Workload from Worker 4: [0.6, 0.4, 0.3]
# Workload from Worker 3: [0.6, 0.4, 0.4]
# Workload from Worker 2: [0.6, 0.4, 0.4]
# Workload from Worker 4: [0.1, 0.4, 0.4]
# Workload from Worker 3: [0.1, 0.4, 0.9]
# New leader elected! Worker 3
# Workload from Worker 2: [0.1, 0.1, 0.9]
# Workload from Worker 4: [0.2, 0.1, 0.9]
# Workload from Worker 3: [0.2, 0.1, 0.2]
# Workload from Worker 2: [0.2, 0.4, 0.2]
# Workload from Worker 4: [0.4, 0.4, 0.2]
# Workload from Worker 3: [0.4, 0.4, 0.8]
# Workload from Worker 2: [0.4, 0.7, 0.8]
# Workload from Worker 4: [0.1, 0.7, 0.8]
# Workload from Worker 3: [0.1, 0.7, 0.7]
# Workload from Worker 2: [0.1, 0.4, 0.7]
# Workload from Worker 4: [0.1, 0.4, 0.7]
# Workload from Worker 3: [0.0, 0.4, 0.9]
# Workload from Worker 2: [0.0, 0.7, 0.9]
# Workload from Worker 4: [0.0, 0.7, 0.9]
# Workload from Worker 3: [0.6, 0.7, 0.7]
# Workload from Worker 2: [0.6, 0.9, 0.7]
# Workload from Worker 4: [0.6, 0.9, 0.7]
# New leader elected! Worker 2
# New leader elected! Worker 4
# Workload from Worker 3: [0.2, 0.9, 0.0]
# Workload from Worker 4: [0.2, 0.9, 0.0]
# Workload from Worker 2: [0.2, 0.9, 0.0]
# Workload from Worker 3: [0.2, 0.9, 0.6]
# Workload from Worker 4: [0.2, 0.2, 0.6]
# Workload from Worker 2: [0.2, 0.2, 0.6]
# Workload from Worker 3: [0.8, 0.2, 0.9]
# New leader elected! Worker 3
# Workload from Worker 2: [0.8, 0.9, 0.9]
# Workload from Worker 4: [0.8, 0.9, 0.9]
# Workload from Worker 3: [0.3, 0.9, 0.3]
# Workload from Worker 2: [0.3, 0.3, 0.3]
# Workload from Worker 4: [0.6, 0.3, 0.3]
# Workload from Worker 3: [0.6, 0.3, 0.4]
# Workload from Worker 2: [0.6, 0.3, 0.4]
# Workload from Worker 4: [0.4, 0.3, 0.4]
# Workload from Worker 3: [0.4, 0.3, 0.5]
# Workload from Worker 2: [0.4, 0.6, 0.5]
# Workload from Worker 4: [0.4, 0.6, 0.5]
# Workload from Worker 3: [0.4, 0.6, 0.3]
# Workload from Worker 2: [0.4, 0.8, 0.3]
# Workload from Worker 4: [0.4, 0.8, 0.3]
# New leader elected! Worker 4
# Workload from Worker 3: [0.4, 0.8, 0.1]
# Workload from Worker 2: [0.4, 0.1, 0.1]
# Workload from Worker 4: [0.0, 0.1, 0.1]
# Workload from Worker 3: [0.0, 0.1, 0.6]
# Workload from Worker 2: [0.0, 0.5, 0.6]
# Workload from Worker 4: [0.1, 0.5, 0.6]
# Workload from Worker 3: [0.1, 0.5, 0.2]
# Workload from Worker 2: [0.1, 0.5, 0.2]
# Workload from Worker 4: [1.0, 0.5, 0.2]
# Workload from Worker 3: [1.0, 0.5, 0.0]
# Workload from Worker 2: [1.0, 0.4, 0.0]
# Workload from Worker 4: [1.0, 0.4, 0.0]
# Workload from Worker 3: [0.2, 0.4, 0.1]

# %% [markdown]
# ## Entrega
#
# As respostas deverão ser entregues na parte indicada desse arquivo reservada ao código fonte, no formato [IJulia Notebook](https://github.com/JuliaLang/IJulia.jl), que utiliza tecnologia [Jupyter](https://www.jupyter.org).
#
# O programa deve ser implementado na linguagem de programação [**Julia** versão 1.x](https://julialang.org/downloads/). Seu trabalho será testado na [JuliaBox](https://juliabox.com).
#
# Baixe seu arquivo `.ipynb` e anexe-o ao Google Classroom. Não se esqueça de **testar seu arquivo `.ipynb` na JuliaBox** antes de enviá-lo.
#
#
# ### Forma
#
# O arquivo IJulia Notebook deverá ser entregue ao Professor **exclusivamente através do Google Classroom**.
#
#
#
# A responsabilidade sobre a integridade do arquivo contendo trabalho é exclusivamente dos discentes. Serão ignorados os trabalhos cujos arquivos não conseguirem ser abertos pelo Professor.
#
# ### Prazos
#
# O prazo de entrega está descrito no **Google Classroom**.
#
#
# ## Pontuação extra
#
# O(a) discente que realizar mais tarefas, além do que foi especificado neste trabalho, o professor atribuirá de 0,5 a 1,0 ponto extra a depender da relevância da contribuição no programa. O critério será decidido pelo professor.
#
# O(a) discente deve indicar qual é a tarefa executada. Por exemplo, adição de funcionalidades, armazenamento de dados em arquivo, documentação de código, comentários em inglês sem erros ortográficos, etc.
#
#
# **Plágio** A nota zero será atribuída caso haja qualquer tipo de cópia parcial ou integral assim como as devidas medidas legais. Leia a [cartilha sobre plágio](http://www.noticias.uff.br/arquivos/cartilha-sobre-plagio-academico.pdf).
#
# ## Disclaimer
#
# Esse material foi elaborado pelo [Prof. André Lage Freitas](https://sites.google.com/a/ic.ufal.br/andrelage/) e está licenciado sob a licença _GNU General Public License v3.0_.
